# %% [markdown]
# # Task 1

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading CSV file

# %%
df=pd.read_csv("worldpopulationdata.csv")

# %% [markdown]
# ## Checking top 5 rows data

# %%
df.head(5)
# Out:
#          Series Name  Series Code    Country Name Country Code        2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...  \
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# ...

# %% [markdown]
# ## Checking  data from bottom

# %%
df.tail(5)
# Out:
#                                    Series Name        Series Code  \
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code       2022       2021       2020  \
# 1080  Virgin Islands (U.S.)          VIR  46.613382  46.764444  46.914637
# 1081     West Bank and Gaza          PSE  49.893678  49.877839  49.858957
# 1082            Yemen, Rep.          YEM  50.519031  50.538516  50.554317
# 1083                 Zambia          ZMB  49.344602  49.344951  49.338301
# 1084               Zimbabwe          ZWE  47.214139  47.167153  47.130679
#
#            2019       2018       2017  ...       2010       2009       2008  \
# ...

# %% [markdown]
# ## checking the columns of the dataset

# %%
df.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001'],
#       dtype='object')

# %% [markdown]
# ## sum information from datset

# %%
df.info
# Out:
# <bound method DataFrame.info of                                    Series Name        Series Code  \
# 0                            Population, total        SP.POP.TOTL
# 1                            Population, total        SP.POP.TOTL
# 2                            Population, total        SP.POP.TOTL
# 3                            Population, total        SP.POP.TOTL
# 4                            Population, total        SP.POP.TOTL
# ...                                        ...                ...
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code          2022          2021  \
# 0               Afghanistan          AFG  4.112877e+07  4.009946e+07
# ...

# %%
df.describe()
# Out:
#                2022          2021          2020          2019          2018  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.461378e+07  1.449711e+07  1.437307e+07  1.422876e+07  1.407966e+07
# std    7.832944e+07  7.801505e+07  7.763257e+07  7.712985e+07  7.657562e+07
# min    2.749000e+01  2.732503e+01  2.735104e+01  2.676295e+01  2.573928e+01
# 25%    5.034029e+01  5.035172e+01  5.034171e+01  5.033040e+01  5.033917e+01
# 50%    1.465500e+05  1.463660e+05  1.461650e+05  1.459570e+05  1.457520e+05
# 75%    5.903468e+06  5.856733e+06  5.831404e+06  5.814422e+06  5.774185e+06
# max    1.417173e+09  1.412360e+09  1.411100e+09  1.407745e+09  1.402760e+09
#
#                2017          2016          2015          2014          2013  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.392568e+07  1.376711e+07  1.360705e+07  1.344625e+07  1.328368e+07
# ...

# %% [markdown]
# ## Checking for duplicates values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Checking for missing values

# %%
df.isna().sum()
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %% [markdown]
# ## Reading CSV file

# %%
df=pd.read_csv("worldpopulationdata.csv")

# %%
df
# Out:
#                                    Series Name        Series Code  \
# 0                            Population, total        SP.POP.TOTL
# 1                            Population, total        SP.POP.TOTL
# 2                            Population, total        SP.POP.TOTL
# 3                            Population, total        SP.POP.TOTL
# 4                            Population, total        SP.POP.TOTL
# ...                                        ...                ...
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code          2024          2023  \
# 0               Afghanistan          AFG  3.776950e+08  3.463621e+08
# ...

# %% [markdown]
# ## checking for duplicates values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Checking missing values

# %%
df.isna().sum()
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2024            0
# 2023            0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %% [markdown]
# ## Checking unique values for columns

# %%
print(df['Country Name'].unique())
print("\n Total no of unique countries:",df['Country Name'].nunique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
# ...

# %%
print(df['Country Code'].unique())
print("\n Total no of unique countries Code:",df['Country Code'].nunique())
# Out:
# ['AFG' 'ALB' 'DZA' 'ASM' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'ABW' 'AUS' 'AUT'
#  'AZE' 'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BMU' 'BTN' 'BOL'
#  'BIH' 'BWA' 'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'CPV' 'KHM' 'CMR' 'CAN'
#  'CYM' 'CAF' 'TCD' 'CHI' 'CHL' 'CHN' 'COL' 'COM' 'COD' 'COG' 'CRI' 'CIV'
#  'HRV' 'CUB' 'CUW' 'CYP' 'CZE' 'DNK' 'DJI' 'DMA' 'DOM' 'ECU' 'EGY' 'SLV'
#  'GNQ' 'ERI' 'EST' 'SWZ' 'ETH' 'FRO' 'FJI' 'FIN' 'FRA' 'PYF' 'GAB' 'GMB'
#  'GEO' 'DEU' 'GHA' 'GIB' 'GRC' 'GRL' 'GRD' 'GUM' 'GTM' 'GIN' 'GNB' 'GUY'
#  'HTI' 'HND' 'HKG' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'IMN' 'ISR'
#  'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'PRK' 'KOR' 'XKX' 'KWT' 'KGZ'
#  'LAO' 'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LIE' 'LTU' 'LUX' 'MAC' 'MDG' 'MWI'
#  'MYS' 'MDV' 'MLI' 'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO' 'MNG'
#  'MNE' 'MAR' 'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NCL' 'NZL' 'NIC' 'NER'
#  'NGA' 'MKD' 'MNP' 'NOR' 'OMN' 'PAK' 'PLW' 'PAN' 'PNG' 'PRY' 'PER' 'PHL'
# ...

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df.drop(['Series Name','Country Name'],axis=1,inplace=True)

# %% [markdown]
# ## Extarction of top 10 countries with respect to total population

# %%
#Filter data for total population 
total_population_data = df[df['Series Code']=='SP.POP.TOTL']

#Sort data based on the total population for 2024
total_population_sorted = total_population_data.sort_values(by="2024", ascending=False)

#Get the top ten countries with the highest total population for 2024
total_top_ten_countries = total_population_sorted.head(10)
print("Top ten countries of total population\n")
print(total_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of total population
#
#     Country Code
# 41           CHN
# 161          RUS
# 89           IND
# 7            ARG
# 2            DZA
# 0            AFG
# 206          USA
# 90           IDN
# 149          PAK
# 26           BRA

# %% [markdown]
# # Bar Plot

# %% [markdown]
# ## Top ten countries of total population in year 2020 and 2015

# %%
#create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2020",y="Country Code", data=total_top_ten_countries, palette="coolwarm")
plt.title("Top Ten Countries of total population(2020)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

#create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2015",y="Country Code", data=total_top_ten_countries, palette="coolwarm")
plt.title("Top Ten Countries of total population(2015)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# C:\Users\SAURAV MISHRA\AppData\Local\Temp\ipykernel_2912\3375744940.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2020",y="Country Code", data=total_top_ten_countries, palette="coolwarm")
# C:\Users\SAURAV MISHRA\AppData\Local\Temp\ipykernel_2912\3375744940.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2015",y="Country Code", data=total_top_ten_countries, palette="coolwarm")

# %% [markdown]
# ## Extraction of bottom 10 countries with respect to total population

# %%
#Sort data based on the total population for 2020
total_population_sorted1 = total_population_data.sort_values(by="2020", ascending=True)

#Get the top ten countries with the highest total population for 2020
total_bottom_ten_countries = total_population_sorted1.head(10)
print("Bottom ten countries of total population\n")
print(total_bottom_ten_countries[['Country Code']])
# Out:
# Bottom ten countries of total population
#
#     Country Code
# 201          TUV
# 137          NRU
# 150          PLW
# 27           VGB
# 183          MAF
# 75           GIB
# 164          SMR
# 130          MCO
# 114          LIE
# 172          SXM

# %% [markdown]
# ## Bottom ten countries of total population in year 2020 and 2015

# %%
#create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2020",y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")
plt.title("Bottom Ten Countries of total population(2020)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

#create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2015",y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")
plt.title("Bottom Ten Countries of total population(2015)",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# C:\Users\SAURAV MISHRA\AppData\Local\Temp\ipykernel_2912\558882996.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2020",y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")
# C:\Users\SAURAV MISHRA\AppData\Local\Temp\ipykernel_2912\558882996.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2015",y="Country Code", data=total_bottom_ten_countries, palette="coolwarm")

# %% [markdown]
# ## Extarction of top 10 countries with highest male population

# %%
#filter data for male population 
male_population_data = df[df['Series Code']=='SP.POP.TOTL.MA.IN']

#sort data based on the male population for 2022
male_population_sorted=male_population_data.sort_values(by="2024",ascending=False)

#Get the top 10 countries with the highest male population for 2024
male_top_ten_countries=male_population_sorted .head(10)
print("Top ten countries of male popualtion")
print(male_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of male popualtion
#     Country Code
# 523          IND
# 475          CHN
# 640          USA
# 524          IDN
# 583          PAK
# 460          BRA
# 578          NGA
# 449          BGD
# 595          RUS
# 532          JPN

# %%
#filter data for female population 
female_population_data = df[df['Series Code']=='SP.POP.TOTL.FE.IN']

#sort data based on the male population for 2022
female_population_sorted=female_population_data.sort_values(by="2024",ascending=False)

#Get the top 10 countries with the highest male population for 2024
female_top_ten_countries=female_population_sorted .head(10)
print("Top ten countries of female popualtion")
print(female_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of female popualtion
#     Country Code
# 258          CHN
# 306          IND
# 423          USA
# 307          IDN
# 366          PAK
# 243          BRA
# 361          NGA
# 232          BGD
# 378          RUS
# 315          JPN

# %% [markdown]
# ## Top ten countries with highest male and female populatiom in 2024

# %%
#create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2020",y="Country Code", data=male_top_ten_countries , palette="viridis")
plt.title("Top ten countries of male population(2020)",fontsize=10)
plt.xlabel("Male Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

#create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2015",y="Country Code", data=female_top_ten_countries, palette="viridis")
plt.title("Top ten Countries of female population(2015)",fontsize=10)
plt.xlabel("Female Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# C:\Users\SAURAV MISHRA\AppData\Local\Temp\ipykernel_2912\1903131170.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2020",y="Country Code", data=male_top_ten_countries , palette="viridis")
# C:\Users\SAURAV MISHRA\AppData\Local\Temp\ipykernel_2912\1903131170.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2015",y="Country Code", data=female_top_ten_countries, palette="viridis")

# %% [markdown]
# # Stacked Bar Plot

# %% [markdown]
# ## Top 10 countries with male and female population

# %%
#merge male and femaLe population data on 'Country Code'
merge_data=pd.merge(male_population_data,female_population_data,on="Country Code",suffixes=("_male","_female"))

# %%
#merged data
#calculate the total population for each country (male+female)
merge_data["Total Population"] =merge_data["2024_male"]+merge_data["2024_female"]

# %%
merge_data.head()
# Out:
#     Series Code_male Country Code   2024_male   2023_male   2022_male  \
# 0  SP.POP.TOTL.MA.IN          AFG  19090409.0  17520861.0  20766442.0
# 1  SP.POP.TOTL.MA.IN          ALB   1428828.0   1442176.0   1384548.0
# 2  SP.POP.TOTL.MA.IN          DZA  21756903.0  20556314.0  22862237.0
# 3  SP.POP.TOTL.MA.IN          ASM     23535.0     25240.0     21873.0
# 4  SP.POP.TOTL.MA.IN          AND     38842.0     36628.0     40786.0
#
#     2021_male   2020_male   2019_male   2018_male   2017_male  ...  \
# 0  20254878.0  19692301.0  19090409.0  18549862.0  18028696.0  ...
# 1   1404454.0   1419264.0   1428828.0   1435881.0   1440219.0  ...
# 2  22497244.0  22132899.0  21756903.0  21362603.0  20961313.0  ...
# 3     22289.0     22921.0     23535.0     24134.0     24701.0  ...
# 4     40361.0     39615.0     38842.0     38071.0     37380.0  ...
#
#    2009_female  2008_female  2007_female  2006_female  2005_female  \
# 0   13557331.0   13088192.0   12835340.0   12614497.0   12109086.0
# ...

# %%
#sort data based on total population in descending order
sorted_data = merge_data.sort_values(by="Total Population", ascending=False)

# %% [markdown]
# ## Select the top 10 countries with highest total population

# %%
top_10_countries = sorted_data.head(10)

# %%
#create the staked bar plot
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code",y="2020_female",data=top_10_countries,color="pink",label="female population")
sns.barplot(x="Country Code",y="2020_male",data=top_10_countries,bottom=top_10_countries["2020_female"],color="Blue",label="Male population")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45,ha="right")
plt.show()

# %% [markdown]
# ## Bottom 10 countries with male and female population (2020)

# %%
#select the top 10 countries with the highest total population
bottom_10_countries = sorted_data.tail(10)

# %%
#create the staked bar plot
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code",y="2020_female",data=bottom_10_countries,color="pink",label="female population")
sns.barplot(x="Country Code",y="2020_male",data=bottom_10_countries,bottom=top_10_countries["2020_female"],color="Blue",label="Male population")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45,ha="right")
plt.show()
